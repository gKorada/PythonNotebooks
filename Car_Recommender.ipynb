# %% [markdown]
# <a href="https://colab.research.google.com/github/gKorada/PythonNotebooks/blob/main/Car_Recommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ucimlrepo

# %%
import pandas as pd

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
auto_mpg = fetch_ucirepo(id=9)

# data (as pandas dataframes)
X = auto_mpg.data.features
y = auto_mpg.data.targets
z = auto_mpg.names
# metadata
print(auto_mpg.metadata)

# variable information
print(auto_mpg.variables)
# Out:
# {'uci_id': 9, 'name': 'Auto MPG', 'repository_url': 'https://archive.ics.uci.edu/dataset/9/auto+mpg', 'data_url': 'https://archive.ics.uci.edu/static/public/9/data.csv', 'abstract': 'Revised from CMU StatLib library, data concerns city-cycle fuel consumption', 'area': 'Other', 'tasks': ['Regression'], 'characteristics': ['Multivariate'], 'num_instances': 398, 'num_features': 7, 'feature_types': ['Real', 'Categorical', 'Integer'], 'demographics': [], 'target_col': ['mpg'], 'index_col': ['car_name'], 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1993, 'last_updated': 'Thu Aug 10 2023', 'dataset_doi': '10.24432/C5859H', 'creators': ['R. Quinlan'], 'intro_paper': None, 'additional_info': {'summary': 'This dataset is a slightly modified version of the dataset provided in the StatLib library.  In line with the use by Ross Quinlan (1993) in predicting the attribute "mpg", 8 of the original instances were removed because they had unknown values for 
# ...

# %% [markdown]
# Data Cleaning

# %%
column_names = [
    'mpg', 'cylinders', 'displacement', 'horsepower',
    'weight', 'acceleration', 'model_year', 'origin', 'car_name'
]

car_df = pd.read_csv('/content/drive/MyDrive/auto-mpg.data', delim_whitespace=True, header=None, names=column_names, na_values='?')

car_df.head()
# Out:
# /tmp/ipython-input-3371358629.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   car_df = pd.read_csv('/content/drive/MyDrive/auto-mpg.data', delim_whitespace=True, header=None, names=column_names, na_values='?')
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year  origin                   car_name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# ...

# %%
car_df = pd.read_csv('/content/drive/MyDrive/Ad_table.csv')
car_copy = car_df
car_copy.head()
# Out:
# /tmp/ipython-input-3726710648.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   car_df = pd.read_csv('/content/drive/MyDrive/Ad_table.csv')
#      Maker Genmodel Genmodel_ID   Adv_ID  Adv_year  Adv_month   Color  \
# 0  Bentley   Arnage        10_1  10_1$$1      2018          4  Silver
# 1  Bentley   Arnage        10_1  10_1$$2      2018          6    Grey
# 2  Bentley   Arnage        10_1  10_1$$3      2017         11    Blue
# 3  Bentley   Arnage        10_1  10_1$$4      2018          4   Green
# 4  Bentley   Arnage        10_1  10_1$$5      2017         11    Grey
#
#    Reg_year Bodytype Runned_Miles Engin_size    Gearbox Fuel_type  Price  \
# 0    2000.0   Saloon        60000       6.8L  Automatic    Petrol  21500
# 1    2002.0   Saloon        44000       6.8L  Automatic    Petrol  28750
# 2    2002.0   Saloon        55000       6.8L  Automatic    Petrol  29999
# ...

# %%
car_copy = car_copy.drop(columns=['Genmodel_ID', 'Adv_ID', 'Adv_month', 'Engin_size','Seat_num', 'Door_num', 'Color'])

car_copy.head()
# Out:
#      Maker Genmodel  Adv_year  Reg_year Bodytype Runned_Miles    Gearbox  \
# 0  Bentley   Arnage      2018    2000.0   Saloon        60000  Automatic
# 1  Bentley   Arnage      2018    2002.0   Saloon        44000  Automatic
# 2  Bentley   Arnage      2017    2002.0   Saloon        55000  Automatic
# 3  Bentley   Arnage      2018    2003.0   Saloon        14000  Automatic
# 4  Bentley   Arnage      2017    2003.0   Saloon        61652  Automatic
#
#   Fuel_type  Price
# 0    Petrol  21500
# 1    Petrol  28750
# 2    Petrol  29999
# 3    Petrol  34948
# 4    Petrol  26555

# %%
car_copy.drop(columns = ['Gearbox'], inplace = True)
car_copy.head()
# Out:
#      Maker Genmodel  Adv_year  Reg_year Bodytype Runned_Miles Fuel_type  Price
# 0  Bentley   Arnage      2018    2000.0   Saloon        60000    Petrol  21500
# 1  Bentley   Arnage      2018    2002.0   Saloon        44000    Petrol  28750
# 2  Bentley   Arnage      2017    2002.0   Saloon        55000    Petrol  29999
# 3  Bentley   Arnage      2018    2003.0   Saloon        14000    Petrol  34948
# 4  Bentley   Arnage      2017    2003.0   Saloon        61652    Petrol  26555

# %%
car_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268255 entries, 0 to 268254
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Maker         268255 non-null  object
#  1   Genmodel      268255 non-null  object
#  2   Adv_year      268255 non-null  int64
#  3   Reg_year      268248 non-null  float64
#  4   Bodytype      267301 non-null  object
#  5   Runned_Miles  267200 non-null  object
#  6   Fuel_type     267846 non-null  object
#  7   Price         268255 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 16.4+ MB

# %%
car_copy['Runned_Miles'].isna().sum()
# Out:
# np.int64(1055)

# %%
car_copy['Price'].isna().sum()
# Out:
# np.int64(0)

# %%
car_copy.dropna(inplace = True)

car_copy.isna().sum()
# Out:
# Maker           0
# Genmodel        0
# Adv_year        0
# Reg_year        0
# Bodytype        0
# Runned_Miles    0
# Fuel_type       0
# Price           0
# dtype: int64

# %%
car_copy['Runned_Miles']
# Out:
# 0          60000
# 1          44000
# 2          55000
# 3          14000
# 4          61652
#            ...
# 268249    107000
# 268250      1800
# 268252         6
# 268253      1538
# 268254       500
# Name: Runned_Miles, Length: 265940, dtype: object

# %%
car_copy['Runned_Miles'] = car_copy['Runned_Miles'].astype(int)
car_copy['Price'] = car_copy['Price'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3706905058.py in <cell line: 0>()
# ----> 1 car_copy['Runned_Miles'] = car_copy['Runned_Miles'].astype(int)
#       2 car_copy['Price'] = car_copy['Price'].astype(int)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
# ...

# %% [markdown]
# So I was thinking creating some type of score based on runned miles, price and body type. The runned miles score would be if the car model avg runned miles is a certain number, attribute a score of 1-5 from it. Same concept for the price. Body Type I have no idea honestly, might just use it to help the alogrithim pick based on the user's choice.

# %% [markdown]
# Miles score first

# %%
car_avg = car_copy.groupby('Runned_Miles').mean()
car_avg.head()
